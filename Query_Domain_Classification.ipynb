# %% [markdown]
# # ***Query Domain Classification***

# %% [markdown]
# Importing required Libraries

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV 
from sklearn.metrics import f1_score,precision_score, multilabel_confusion_matrix, accuracy_score,jaccard_score, recall_score, hamming_loss,confusion_matrix
from sklearn.multiclass import OneVsRestClassifier

from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from sklearn.linear_model import SGDClassifier

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# Loading the data

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    ID                                              Title      Domain
# 0   1  What is good in a decision tree, a large or a ...  Techniques
# 1   2  Training data only contains single positive label  Techniques
# 2   3  Calculating percentage contribution of a negat...  Techniques
# 3   4                   Unable to open solution checker!  Hackathons
# 4   5                                   User Name Change        Misc

# %%
#lets check the shape of the data 
df.shape
# Out:
# (3845, 3)

# %%
#lets check the data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3845 entries, 0 to 3844
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      3845 non-null   int64
#  1   Title   3834 non-null   object
#  2   Domain  3845 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 90.2+ KB

# %% [markdown]
# Lets see how the Query  look like

# %%
df['Title'][0]
# Out:
# 'What is good in a decision tree, a large or a small leaf size?'

# %%
#Create a new subset of the data by only taking the 2nd column onwards (comments and categories)
#data_count = df.iloc[:,1:].sum()

# %%
#data_count

# %% [markdown]
# Feature Engineering

# %% [markdown]
# Text processing

# %%
#importing required libraries for text processing 
import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import wordnet
from nltk.corpus import wordnet as wn
#import lemmatizer

# %%
#function for lemmatization
def lemm(text):
    lemmatizer = wordnet.WordNetLemmatizer()
    word_tokens = word_tokenize(text)
    lemmas = [lemmatizer.lemmatize(word, wn.VERB) for word in word_tokens]
    
    return " ".join(lemmas)
#function for removing stopwords    
def rem_stopwords(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    filtered_text = [word for word in word_tokens if word not in string.punctuation]
    filtered_text = [word for word in filtered_text if word not in stop_words]
    return " ".join(filtered_text)

def decontracted(text):
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can\'t", "can not", text)
    text = re.sub(r"im", "i am", text)
    text = re.sub(r"yo", "you",text)
    text = re.sub(r"youu", "you",text)
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'t", " not", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'m", " am", text)
    text = re.sub(r'http\S+', '', text) #removing urls
    return text

# %%
df.head()
# Out:
#    ID                                              Title      Domain
# 0   1  What is good in a decision tree, a large or a ...  Techniques
# 1   2  Training data only contains single positive label  Techniques
# 2   3  Calculating percentage contribution of a negat...  Techniques
# 3   4                   Unable to open solution checker!  Hackathons
# 4   5                                   User Name Change        Misc

# %%
df.isna().sum()
# Out:
# ID         0
# Title     11
# Domain     0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# ID        0
# Title     0
# Domain    0
# dtype: int64

# %%
df.dtypes
# Out:
# ID         int64
# Title     object
# Domain    object
# dtype: object

# %%
#  df['Title'] = df.Title.apply(lambda x: x.lower()) #lowering all text

# %%
def text_proc(df):
    
    df['Title'] = df.Title.apply(lambda x: x.lower()) #lowering all text
    df['Title'] = df.Title.apply(lambda x: re.sub(r'\d+','',x)) #removing numbers
    df['Title'] = df.Title.apply(lambda x: re.sub(r'\n',' ',x)) #removing \n
    df['Title'] = df.Title.apply(lambda x: decontracted(x))
    df['Title'] = df.Title.apply(lambda x: lemm(x))
    
    #removing punctuations
    translator = str.maketrans('','', string.punctuation)
    df['Title'] = df.Title.apply(lambda x : x.translate(translator))
    df['Title'] = df.Title.apply(lambda x: rem_stopwords(x))
text_proc(df)

# %%
#import nltk
#nltk.download('all')

# %%
#lets have a look at data set now
df
# Out:
#         ID                                              Title      Domain
# 0        1           good decision tree large small leaf size  Techniques
# 1        2           train data contain single positive label  Techniques
# 2        3  calculate percentage contribution negative com...  Techniques
# 3        4                       unable open solution checker  Hackathons
# 4        5                                   user name change        Misc
# ...    ...                                                ...         ...
# 3840  3841           find practice problems linear regression   Resources
# 3841  3842                          run java code gpu aparapi       Tools
# 3842  3843  rpython script need assign cluster id po recor...       Tools
# 3843  3844                         separate column two column  Techniques
# 3844  3845                               cluster segmentation  Techniques
#
# [3834 rows x 3 columns]

# %% [markdown]
# EDA

# %%
import wordcloud
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
def wordcloud(df, label):
    
    # Print only rows where the toxic category label value is 1 (ie. the comment is toxic)
    subset=df[df[label]==1]
    text=subset.Title.values
    wc= WordCloud(background_color="white",max_words=4000)

    wc.generate(" ".join(text))

    plt.figure(figsize=(20,20))
    plt.subplot(221)
    plt.axis("off")
    plt.title("Words frequented in {}".format(label), fontsize=20)
    plt.imshow(wc.recolor(colormap= 'gist_earth' , random_state=244))

# %%
#df_mal = df.loc[:,['ID','Title','Domain']]

# %%
#wordcloud(df, 'Domain')

# %% [markdown]
# Model building

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.multiclass import OneVsRestClassifier

tfidf = TfidfVectorizer(analyzer='word',max_features = 2000)

# %%
x = tfidf.fit_transform(df.Title)

# %%
x.shape
# Out:
# (3834, 2000)

# %%
y = df.Domain
print(y.value_counts())
from sklearn.preprocessing import LabelEncoder
# Create a label encoder object
label_encoder = LabelEncoder()

# Fit the encoder on the target column and transform it
y = label_encoder.fit_transform(y)
# Out:
# Techniques    1852
# Tools          917
# Career         437
# Hackathons     262
# Resources      170
# Other          122
# Misc            74
# Name: Domain, dtype: int64

# %%
np.unique(y, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  array([ 437,  262,   74,  122,  170, 1852,  917]))

# %%
x
# Out:
# <3834x2000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 17957 stored elements in Compressed Sparse Row format>

# %%
y
# Out:
# array([5, 5, 5, ..., 6, 5, 5])

# %%
tfidf.vocabulary_
# Out:
# {'good': 677,
#  'decision': 427,
#  'tree': 1792,
#  'large': 846,
#  'small': 1538,
#  'size': 1527,
#  'train': 1764,
#  'data': 405,
#  'contain': 341,
#  'single': 1523,
#  'positive': 1168,
#  'label': 841,
#  'calculate': 222,
#  'percentage': 1112,
#  'negative': 1016,
#  'component': 318,
#  'unable': 1824,
#  'open': 1062,
#  'solution': 1548,
#  'checker': 269,
#  'user': 1863,
#  'name': 1006,
#  'change': 260,
#  'decide': 425,
#  'curve': 389,
#  'fit': 621,
#  'model': 970,
#  'epochs': 546,
#  'neural': 1022,
#  'network': 1021,
#  'chatbot': 264,
#  'give': 672,
#  'answer': 107,
#  'ames': 59,
#  'repository': 1369,
#  'plot': 1135,
#  'google': 679,
#  'map': 919,
#  'python': 1300,
#  'algorithm': 33,
#  'choose': 274,
#  'response': 1387,
#  'weak': 1914,
#  'code': 295,
#  'throw': 1735,
#  'error': 550,
#  'trial': 1795,
#  'nonnumeric': 1037,
#  'argument': 121,
#  'binary': 192,
#  'operator': 1065,
#  'call': 225,
#  'reduce': 1342,
#  'learn': 860,
#  'path': 1104,
#  'pick': 1122,
#  'become': 174,
#  'scientist': 1449,
#  'build': 214,
#  'computer': 323,
#  'vision': 1895,
#  'nlp': 1027,
#  'applications': 114,
#  'score': 1455,
#  'submission': 1622,
#  'leaderboard': 857,
#  'one': 1057,
#  'better': 184,
#  'master': 927,
#  'sas': 1437,
#  'want': 1909,
#  'default': 433,
#  'threshold': 1732,
#  'apply': 115,
#  'logistic': 893,
#  'regression': 1348,
#  'sklearn': 1534,
#  'need': 1015,
#  'help': 718,
#  'go': 676,
#  'deep': 432,
#  'please': 1134,
#  'guide': 696,
#  'course': 367,
#  'group': 690,
#  'server': 1487,
#  'select': 1472,
#  'record': 1341,
#  'certain': 252,
#  'column': 302,
#  'kind': 834,
#  'helpful': 719,
#  'total': 1757,
#  'count': 365,
#  'month': 978,
#  'year': 1981,
#  'problem': 1242,
#  'next': 1025,
#  'week': 1918,
#  'future': 652,
#  'forecast': 629,
#  'customer': 391,
#  'number': 1046,
#  'expect': 577,
#  'alarm': 31,
#  'example': 566,
#  'xgboost': 1965,
#  'use': 1861,
#  'julia': 821,
#  'dt': 501,
#  'dateti': 418,
#  'value': 1868,
#  'recommend': 1337,
#  'specs': 1563,
#  'science': 1447,
#  'difference': 465,
#  'function': 650,
#  'ggplot': 669,
#  'package': 1087,
#  'price': 1226,
#  'opti': 1070,
#  'amization': 69,
#  'find': 617,
#  'dependent': 443,
#  'variable': 1873,
#  'test': 1709,
#  'dataset': 414,
#  'datafest': 409,
#  'back': 157,
#  'sample': 1432,
#  'analysis': 94,
#  'retail': 1394,
#  'consumer': 339,
#  'industry': 768,
#  'si': 1517,
#  'amilar': 63,
#  'college': 299,
#  'best': 183,
#  'practice': 1183,
#  'machine': 905,
#  'lean': 859,
#  'amize': 70,
#  'qlikview': 1304,
#  'document': 489,
#  'high': 723,
#  'mean': 942,
#  'correlation': 359,
#  'subtract': 1630,
#  'degree': 436,
#  'awesome': 151,
#  'ipython': 805,
#  'notebooks': 1044,
#  'dummy': 505,
#  'encode': 532,
#  'order': 1074,
#  'categorical': 241,
#  'knn': 837,
#  'regard': 1345,
#  'business': 216,
#  'analytics': 98,
#  'churn': 276,
#  'set': 1491,
#  'technique': 1695,
#  'web': 1915,
#  'scrap': 1457,
#  'bootstrap': 204,
#  'work': 1939,
#  'boost': 203,
#  'access': 5,
#  'specific': 1560,
#  'part': 1098,
#  'list': 882,
#  'fill': 613,
#  'miss': 964,
#  'many': 918,
#  'condition': 328,
#  'fail': 601,
#  'remove': 1357,
#  'observations': 1052,
#  'less': 867,
#  'frequency': 642,
#  'effect': 516,
#  'cross': 378,
#  'validation': 1866,
#  'complexity': 317,
#  'analyst': 95,
#  'offer': 1054,
#  'movie': 982,
#  'ticket': 1738,
#  'book': 201,
#  'websites': 1917,
#  'unstable': 1845,
#  'output': 1080,
#  'environment': 545,
#  'tool': 1750,
#  'libraries': 870,
#  'perform': 1113,
#  'tableau': 1674,
#  'tb': 1684,
#  'available': 149,
#  'download': 494,
#  'click': 287,
#  'prediction': 1198,
#  'retain': 1395,
#  'statement': 1583,
#  'skills': 1531,
#  'person': 1115,
#  'career': 231,
#  'expression': 589,
#  'base': 165,
#  'card': 230,
#  'approach': 116,
#  'wouldo': 1954,
#  'know': 839,
#  'megastar': 950,
#  'convert': 350,
#  'continous': 344,
#  'variables': 1874,
#  'ii': 753,
#  'replace': 1364,
#  'particular': 1100,
#  'ampute': 87,
#  'apriori': 119,
#  'algorithms': 34,
#  'read': 1326,
#  'date': 417,
#  'ti': 1736,
#  'ame': 52,
#  'information': 772,
#  'parse': 1097,
#  'keyword': 832,
#  'relationships': 1354,
#  'create': 371,
#  'index': 764,
#  'series': 1485,
#  'matplotlib': 934,
#  'xaxis': 1961,
#  'multiple': 998,
#  'gpu': 682,
#  'amultaneously': 90,
#  'setup': 1494,
#  'ai': 28,
#  'zip': 1996,
#  'file': 612,
#  'directly': 474,
#  'post': 1170,
#  'years': 1982,
#  'experience': 579,
#  'chance': 259,
#  'switch': 1661,
#  'free': 641,
#  'beginners': 176,
#  'vs': 1907,
#  'density': 441,
#  'cluster': 292,
#  'numerical': 1048,
#  'field': 610,
#  'drop': 499,
#  'present': 1220,
#  'place': 1127,
#  'understaing': 1827,
#  'significance': 1520,
#  'roc': 1417,
#  'compare': 311,
#  'two': 1818,
#  'obtain': 1053,
#  'lm': 884,
#  'new': 1023,
#  'plz': 1143,
#  'tutorial': 1814,
#  'scratch': 1460,
#  'interpret': 794,
#  'result': 1392,
#  'term': 1708,
#  'increase': 760,
#  'decrease': 431,
#  'irregular': 808,
#  'microsoft': 960,
#  'introduction': 801,
#  'edx': 515,
#  'get': 667,
#  'point': 1149,
#  'participate': 1099,
#  'skilltest': 1532,
#  'rename': 1358,
#  'polynomials': 1156,
#  'stock': 1597,
#  'market': 923,
#  'table': 1673,
#  'form': 632,
#  'matrix': 936,
#  'input': 773,
#  'split': 1567,
#  'element': 522,
#  'wise': 1928,
#  'notebook': 1043,
#  'creation': 372,
#  'shiny': 1506,
#  'start': 1578,
#  'explore': 586,
#  'big': 187,
#  'technology': 1699,
#  'freshers': 645,
#  'factor': 599,
#  'integer': 784,
#  'vari': 1872,
#  'randomforest': 1312,
#  'predictive': 1200,
#  'frame': 637,
#  'box': 208,
#  'detection': 453,
#  'opencv': 1063,
#  'shift': 1505,
#  'mainframes': 909,
#  'layer': 851,
#  'extract': 592,
#  'twitter': 1817,
#  'store': 1598,
#  'explain': 582,
#  'node': 1031,
#  'hadoop': 703,
#  'bigdata': 188,
#  'mckinsey': 941,
#  'hackathon': 700,
#  'healthcare': 716,
#  'th': 1722,
#  'loan': 886,
#  'thoughts': 1728,
#  'article': 128,
#  'scientists': 1450,
#  'dead': 423,
#  'raw': 1323,
#  'object': 1050,
#  'resources': 1384,
#  'media': 946,
#  'mix': 965,
#  'lasso': 847,
#  'shrink': 1514,
#  'di': 460,
#  'amensions': 56,
#  'segmentation': 1471,
#  'multi': 992,
#  'classification': 281,
#  'analyze': 100,
#  'different': 467,
#  'zscore': 1998,
#  'predict': 1197,
#  'cosine': 362,
#  'amilarity': 64,
#  'rd': 1325,
#  'instance': 780,
#  'studio': 1613,
#  'adjust': 18,
#  'square': 1572,
#  'transfer': 1774,
#  'final': 615,
#  'character': 261,
#  'standard': 1574,
#  'format': 633,
#  'ho': 730,
#  'confusion': 331,
#  'auc': 140,
#  'bunch': 215,
#  'doc': 488,
#  'docx': 490,
#  'ph': 1120,
#  'require': 1372,
#  'review': 1402,
#  'research': 1375,
#  'purpose': 1290,
#  'amplement': 74,
#  'another': 105,
#  'mine': 961,
#  'svm': 1655,
#  'avoid': 150,
#  'trap': 1788,
#  'naive': 1005,
#  'bay': 171,
#  'classifier': 282,
#  'univariate': 1837,
#  'bivariate': 194,
#  'pls': 1139,
#  'rnn': 1415,
#  'amplementation': 75,
#  'stemmer': 1594,
#  'nltk': 1028,
#  'library': 871,
#  'make': 911,
#  'stationary': 1587,
#  'options': 1072,
#  'selection': 1473,
#  'unstructured': 1847,
#  'non': 1034,
#  'linear': 878,
#  'key': 830,
#  'position': 1167,
#  'understand': 1828,
#  'question': 1307,
#  'task': 1682,
#  'techniques': 1696,
#  'speech': 1564,
#  'text': 1715,
#  'conversion': 349,
#  'entity': 543,
#  'recognition': 1335,
#  'measure': 943,
#  'central': 250,
#  'tendency': 1705,
#  'li': 869,
#  'amitations': 68,
#  'exploratory': 585,
#  'gb': 657,
#  'cv': 395,
#  'random': 1311,
#  'forest': 631,
#  'oppurtunities': 1068,
#  'mnist': 968,
#  'digit': 470,
#  'query': 1306,
#  'normalization': 1040,
#  'gradient': 684,
#  'adaboost': 15,
#  'amage': 42,
#  'product': 1250,
#  'combine': 305,
#  'mart': 925,
#  'sales': 1431,
#  'interview': 798,
#  'case': 237,
#  'study': 1615,
#  'check': 268,
#  'cost': 363,
#  'institute': 782,
#  'ways': 1913,
#  'face': 594,
#  'accuracy': 8,
#  'handle': 706,
#  'log': 890,
#  'tokenization': 1747,
#  'word': 1935,
#  'senti': 1480,
#  'ament': 57,
#  'general': 661,
#  'pattern': 1105,
#  'respect': 1386,
#  'program': 1258,
#  'choice': 273,
#  'critical': 377,
#  'placement': 1129,
#  'graduate': 685,
#  'duration': 507,
#  'take': 1679,
#  'service': 1489,
#  'private': 1233,
#  'lb': 853,
#  'publish': 1286,
#  'anybody': 108,
#  'kaggle': 825,
#  'competition': 313,
#  'join': 818,
#  'specify': 1562,
#  'highly': 726,
#  'ambalance': 49,
#  'seriespractise': 1486,
#  'amprove': 82,
#  'performance': 1114,
#  'must': 1002,
#  'dbscan': 422,
#  'without': 1930,
#  'guy': 698,
#  'prediciton': 1196,
#  'connect': 333,
#  'portfoliowide': 1165,
#  'level': 868,
#  'retrieve': 1397,
#  'embed': 528,
#  'fine': 618,
#  'tune': 1812,
#  'bert': 182,
#  'job': 817,
#  'knowledge': 840,
#  'report': 1367,
#  'professionals': 1256,
#  'methods': 956,
#  'bag': 161,
#  'affect': 25,
#  'assign': 131,
#  'weight': 1919,
#  'match': 928,
#  'skill': 1530,
#  'financial': 616,
#  'excel': 568,
#  'source': 1554,
#  'social': 1546,
#  'run': 1429,
#  'hours': 734,
#  'categories': 242,
#  'instead': 781,
#  'symbols': 1664,
#  'mini': 962,
#  'datahack': 412,
#  'fix': 624,
#  'range': 1314,
#  'treat': 1790,
#  'natural': 1011,
#  'language': 845,
#  'process': 1247,
#  'doubt': 493,
#  'bi': 185,
#  'power': 1176,
#  'consumption': 340,
#  'various': 1876,
#  'equipments': 549,
#  'move': 981,
#  'medical': 948,
#  'chart': 262,
#  'xli': 1970,
#  'amputation': 85,
#  'advantage': 22,
#  'ts': 1806,
#  'logic': 891,
#  'behind': 180,
#  'command': 307,
#  'geomjitter': 666,
#  'install': 778,
#  'tensorflow': 1707,
#  'windows': 1927,
#  'anaconda': 92,
#  'repeat': 1361,
#  'whole': 1925,
#  'vector': 1877,
#  'regularization': 1350,
#  'overfitting': 1083,
#  'underfitting': 1826,
#  'signify': 1522,
#  'essential': 553,
#  'visualizations': 1899,
#  'predictproba': 1203,
#  'centre': 251,
#  'assistance': 133,
#  'load': 885,
#  'previous': 1224,
#  'save': 1438,
#  'workspace': 1945,
#  'rstudio': 1427,
#  'old': 1056,
#  'hackathons': 701,
#  'suitability': 1637,
#  'warn': 1910,
#  'numeric': 1047,
#  'logical': 892,
#  'return': 1398,
#  'na': 1004,
#  'self': 1474,
#  'replication': 1366,
#  'dashboards': 403,
#  'feature': 606,
#  'boruta': 205,
#  'necessary': 1014,
#  'parameter': 1094,
#  'look': 897,
#  'ubuntu': 1822,
#  'residual': 1378,
#  'people': 1110,
#  'outliers': 1079,
#  'smlogit': 1543,
#  'singular': 1524,
#  'basic': 167,
#  'ml': 966,
#  'like': 875,
#  'iit': 755,
#  'isi': 810,
#  'proper': 1268,
#  'growth': 693,
#  'unix': 1839,
#  'amestamp': 61,
#  'project': 1263,
#  'days': 420,
#  'statements': 1584,
#  'aws': 152,
#  'ec': 509,
#  'video': 1884,
#  'guidance': 695,
#  'say': 1439,
#  'errors': 552,
#  'normally': 1042,
#  'distribute': 484,
#  'crowd': 380,
#  'sap': 1435,
#  'functional': 651,
#  'mathematical': 932,
#  'sort': 1552,
#  'faster': 605,
#  'manipulation': 917,
#  'cloud': 290,
#  'stack': 1573,
#  'bar': 164,
#  'issue': 811,
#  'amproving': 83,
#  'caretensemble': 233,
#  'deal': 424,
#  'syntax': 1667,
#  'spyder': 1569,
#  'invalid': 803,
#  'hide': 721,
#  'show': 1513,
#  'overlay': 1084,
#  'line': 877,
#  'distributions': 486,
#  'recommender': 1340,
#  'systems': 1670,
#  'ensemble': 539,
#  'search': 1462,
#  'relate': 1352,
#  'transition': 1782,
#  'engineer': 536,
#  'eda': 511,
#  'attribute': 138,
#  'piwik': 1126,
#  'standardize': 1576,
#  'distance': 482,
#  'swift': 1659,
#  'nonit': 1035,
#  'professional': 1255,
#  'amount': 72,
#  'mask': 926,
#  'class': 280,
#  'problems': 1243,
#  'dynamic': 508,
#  'solve': 1550,
#  'ample': 73,
#  'association': 134,
#  'rule': 1428,
#  'items': 813,
#  'hypothesis': 741,
#  'customers': 392,
#  'travel': 1789,
#  'hash': 711,
#  'black': 195,
#  'friday': 646,
#  'pg': 1116,
#  'diploma': 473,
#  'manipal': 916,
#  'global': 675,
#  'visualization': 1898,
#  'right': 1407,
#  'type': 1820,
#  'graph': 686,
#  'histogram': 728,
#  'admission': 20,
#  'praxis': 1187,
#  'school': 1446,
#  'compute': 322,
#  'distribution': 485,
#  'print': 1229,
#  'every': 563,
#  'page': 1088,
#  'dashboard': 402,
#  'scrapy': 1459,
#  'actual': 13,
#  'relative': 1355,
#  'scale': 1442,
#  'ms': 985,
#  'ds': 500,
#  'grad': 683,
#  'advice': 23,
#  'shape': 1502,
#  'tensor': 1706,
#  'placeholder': 1128,
#  'discussions': 480,
#  'comprehensive': 320,
#  'beginner': 175,
#  'cod': 294,
#  'tabulate': 1676,
#  'xx': 1979,
#  'hire': 727,
#  'amportance': 79,
#  'probability': 1239,
#  'margins': 921,
#  'specificity': 1561,
#  'sensitivity': 1478,
#  'math': 931,
#  'svmradial': 1657,
#  'msbi': 986,
#  'powerbi': 1177,
#  'rsquared': 1426,
#  'depend': 442,
#  'postgraduate': 1173,
#  'statistical': 1589,
#  'amport': 78,
#  'csv': 382,
#  'public': 1283,
#  'preprocessing': 1215,
#  'youlo': 1986,
#  'bound': 206,
#  'ordinal': 1075,
#  'extraction': 593,
#  'rankdeficient': 1316,
#  'may': 939,
#  'glm': 673,
#  'exponential': 587,
#  'operators': 1066,
#  'resourcestraining': 1385,
#  'preparation': 1211,
#  'message': 954,
#  'suggestions': 1635,
#  'bank': 163,
#  'possible': 1169,
#  'anova': 106,
#  'metric': 957,
#  'unit': 1836,
#  'variance': 1875,
#  'display': 481,
#  'symbol': 1663,
#  'generate': 663,
#  'dtablefilter': 502,
#  'merge': 953,
#  'statistics': 1592,
#  'transpose': 1787,
#  'higher': 724,
#  'amension': 53,
#  'users': 1864,
#  'knocktober': 838,
#  'share': 1503,
#  'solutions': 1549,
#  'suitable': 1638,
#  'export': 588,
#  'pdf': 1108,
#  'mode': 969,
#  'hdfs': 713,
#  'hbase': 712,
#  'alternative': 40,
#  'predictions': 1199,
#  'clinical': 288,
#  'amportant': 80,
#  'think': 1727,
#  'msc': 987,
#  'fresher': 644,
#  'prepare': 1212,
#  'conjoint': 332,
#  'modify': 972,
#  'kernel': 829,
#  'cumulative': 384,
#  'gain': 654,
#  'titanic': 1741,
#  'lower': 901,
#  'resolve': 1382,
#  'truncatedsvd': 1802,
#  'determine': 454,
#  'goodness': 678,
#  'mice': 959,
#  'automate': 146,
#  'valueerror': 1869,
#  'add': 16,
#  'false': 603,
#  'hoglm': 731,
#  'correspond': 361,
#  'categorial': 240,
#  'predictor': 1201,
#  'continuous': 346,
#  'target': 1681,
#  'first': 620,
#  'nonlinear': 1036,
#  'way': 1912,
#  'datatable': 416,
#  'resnet': 1380,
#  'caffe': 221,
#  'loop': 898,
#  'vectors': 1878,
#  'arrange': 126,
#  'elements': 523,
#  'row': 1422,
#  'hack': 699,
#  'strategic': 1602,
#  'cheat': 266,
#  'sheet': 1504,
#  'movielens': 983,
#  'algo': 32,
#  'latent': 849,
#  'allocation': 37,
#  'common': 309,
#  'able': 2,
#  'submit': 1623,
#  'locally': 888,
#  'shinyappio': 1507,
#  'protect': 1276,
#  'amputations': 86,
#  'maxi': 938,
#  'amum': 91,
#  'likelihood': 876,
#  'seasonal': 1463,
#  'ari': 123,
#  'ama': 41,
#  'recommendation': 1338,
#  'system': 1669,
#  'explanation': 583,
#  'domain': 491,
#  'technical': 1694,
#  'proc': 1244,
#  'sql': 1570,
#  'prevent': 1222,
#  'someone': 1551,
#  'copy': 354,
#  'cell': 247,
#  'worksheet': 1943,
#  'gini': 670,
#  'stuff': 1616,
#  'auto': 145,
#  'typeerror': 1821,
#  'scalar': 1441,
#  'array': 127,
#  'pandas': 1089,
#  'within': 1929,
#  'arr': 125,
#  'keyerror': 831,
#  'transgender': 1780,
#  'eigen': 520,
#  'pca': 1107,
#  'option': 1071,
#  'slack': 1535,
#  'live': 883,
#  'chat': 263,
#  'equation': 548,
#  'sparse': 1558,
#  'method': 955,
#  'state': 1582,
#  'amal': 44,
#  'pytorch': 1301,
#  'iris': 806,
#  'contour': 347,
#  'detect': 452,
#  'color': 301,
#  'length': 865,
#  'shorter': 1512,
#  'item': 812,
#  'tag': 1678,
#  'comma': 306,
#  'separate': 1481,
#  'stream': 1607,
#  'software': 1547,
#  'infinite': 770,
#  'null': 1045,
#  'survival': 1653,
#  'develop': 455,
#  'deploy': 444,
#  'insert': 774,
#  'dataframe': 410,
#  'online': 1060,
#  'us': 1859,
#  'unsupervised': 1848,
#  'tutorials': 1815,
#  'practie': 1185,
#  'cause': 246,
#  'amputing': 88,
#  'rat': 1319,
#  'vote': 1906,
#  'correct': 356,
#  'predication': 1192,
#  'bigmart': 190,
#  'coefficient': 296,
#  'lda': 854,
#  'undo': 1829,
#  'mechanical': 945,
#  'pursue': 1291,
#  'pros': 1274,
#  'con': 324,
#  'java': 815,
#  'columns': 303,
#  'delete': 438,
#  'tabs': 1675,
#  'unique': 1835,
#  'interaction': 787,
#  'id': 744,
#  'events': 562,
#  'kmeans': 835,
#  'amages': 43,
#  'keras': 828,
#  'nn': 1029,
#  'original': 1076,
#  'intermediate': 790,
#  'transform': 1775,
#  'parameters': 1095,
#  'wns': 1932,
#  'wizard': 1931,
#  'rmse': 1413,
#  'practiceproblemti': 1184,
#  'ameseries': 60,
#  'suggest': 1633,
#  'per': 1111,
#  'heatmap': 717,
#  'san': 1434,
#  'francisco': 639,
#  'cri': 374,
#  'suggestion': 1634,
#  'certification': 254,
#  'classify': 284,
#  'incident': 756,
#  'string': 1608,
#  'pivot': 1125,
#  'filter': 614,
#  'amensionality': 55,
#  'reduction': 1343,
#  'engines': 537,
#  'application': 113,
#  'outlier': 1078,
#  'multivariate': 1000,
#  'publicprivate': 1285,
#  'complete': 315,
#  'powerful': 1178,
#  'production': 1252,
#  'sell': 1475,
#  'recognize': 1336,
#  'amporting': 81,
#  'andrew': 101,
#  'ng': 1026,
#  'multicollinearity': 994,
#  'ideas': 748,
#  'curated': 386,
#  'activity': 12,
#  'absence': 3,
#  'efficiency': 517,
#  'entropy': 544,
#  'rmd': 1411,
#  'normal': 1039,
#  'role': 1418,
#  'really': 1331,
#  'executive': 573,
#  'certificate': 253,
#  'pos': 1166,
#  'along': 38,
#  'lemmatization': 864,
#  'mathematics': 933,
#  'location': 889,
#  'thresold': 1733,
#  'material': 930,
#  'center': 249,
#  'ask': 130,
#  'priority': 1231,
#  'consider': 335,
#  'seasonality': 1464,
#  'basket': 169,
#  'would': 1950,
#  'crack': 370,
#  'upcoming': 1851,
#  'lord': 899,
#  'hana': 704,
#  'manage': 913,
#  'potential': 1175,
#  'skew': 1528,
#  'randomly': 1313,
#  'control': 348,
#  'population': 1162,
#  'driver': 498,
#  'behaviour': 179,
#  'speed': 1565,
#  'angle': 102,
#  'pollution': 1154,
#  'cnn': 293,
#  'cat': 238,
#  'statistician': 1591,
#  'apache': 110,
#  'spark': 1557,
#  'varaible': 1871,
#  'memory': 952,
#  'effort': 519,
#  'esti': 555,
#  'leader': 856,
#  'board': 198,
#  'rank': 1315,
#  'fetch': 609,
#  'grow': 692,
#  'team': 1689,
#  'lead': 855,
#  'company': 310,
#  'support': 1649,
#  'distinct': 483,
#  'capabilities': 227,
#  'firm': 619,
#  'activation': 11,
#  'yn': 1985,
#  'tweet': 1816,
#  'app': 112,
#  'hot': 733,
#  'predicitive': 1195,
#  'sum': 1639,
#  'components': 319,
#  'equal': 547,
#  'link': 880,
#  'site': 1526,
#  'hierarchical': 722,
#  'tip': 1740,
#  'kfold': 833,
#  'represent': 1370,
#  'significant': 1521,
#  'benchmark': 181,
#  'premier': 1210,
#  'league': 858,
#  'difficulty': 469,
#  'newbie': 1024,
#  'portfolio': 1163,
#  ...}

# %%
#lets check the shape of x and y
x.shape, y.shape
# Out:
# ((3834, 2000), (3834,))

# %% [markdown]
# ## **Spliting data into train and test sets**

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25, random_state = 42)

# %%
#lets define different algorithms
svc = LinearSVC()
lr = LogisticRegression(solver='lbfgs')
mnb = MultinomialNB()
lgb = LGBMClassifier()
sgd = SGDClassifier()

# %%
#function for printing score
def print_score(y_pred,clf):
    print('classifier:',clf.__class__.__name__)
    #print("Jaccard score: {}".format(jaccard_score(y_test,y_pred,average='micro')))
    print("Accuracy score: {}".format(accuracy_score(y_test,y_pred)))
    print("f1_score: {}".format(f1_score(y_test,y_pred,average='micro')))
    print("Precision : ", precision_score(y_test,y_pred,average='micro'))
    print("Recall: {}".format(recall_score(y_test,y_pred,average='micro')))
   # print("Hamming loss: ", hamming_loss(y_test,y_pred))
    print("Confusion matrix:\n ", confusion_matrix(y_test,y_pred))
    print('========================================\n')

# %%
#models with evaluation using OneVsRestClassifier
for classifier in [svc,lr,mnb,sgd,lgb]:
   classifier.fit(x_train,y_train)
   y_pred = classifier.predict(x_test)
   print_score(y_pred, classifier)
# Out:
# classifier: LinearSVC
# Accuracy score: 0.6548488008342023
# f1_score: 0.6548488008342023
# Precision :  0.6548488008342023
# Recall: 0.6548488008342023
# Confusion matrix:
#   [[ 93   0   0   1   3  15   5]
#  [  1  27   0   0   0  30   3]
#  [  3   0   0   1   1  11   3]
#  [  2   0   0   1   5  23   3]
#  [  8   1   0   4   6  22   5]
#  [  7  10   3   1   2 382  40]
#  [  4   0   1   0   3 110 119]]
# ========================================
#
# classifier: LogisticRegression
# Accuracy score: 0.6475495307612096
# f1_score: 0.6475495307612096
# Precision :  0.6475495307612096
# Recall: 0.6475495307612096
# Confusion matrix:
#   [[ 81   0   0   0   1  32   3]
#  [  0  21   0   0   0  40   0]
#  [  4   0   0   0   0  13   2]
#  [  2   0   0   0   1  28   3]
#  [  9   1   0   0   2  32   2]
#  [  4   5   0   0   0 403  33]
#  [  2   0   0   0   0 121 114]]
# ========================================
#
# classifier: MultinomialNB
# Accuracy score: 0.6517205422314911
# f1_score: 0.6517205422314911
# Precision :  0.6517205422314911
# Recall: 0.6517205422314911
# Confusion matrix:
#   [[ 92   0   0   0   0  21   4]
#  [  2  14   0   0   0  43   2]
#  [  1   0   0   0   0  17   1]
#  [  0   0   0   0   0  31   3]
#  [  5   1   0   0   0  39   1]
#  [  4   0   0   0   0 420  21]
#  [  4   0   0   0   0 134  99]]
# ========================================
#
# classifier: SGDClassifier
# Accuracy score: 0.6558915537017727
# f1_score: 0.6558915537017727
# Precision :  0.6558915537017727
# Recall: 0.6558915537017727
# Confusion matrix:
#   [[ 94   0   0   1   3  14   5]
#  [  2  31   0   0   2  23   3]
#  [  2   0   0   1   1  11   4]
#  [  2   1   0   2   5  21   3]
#  [  9   1   0   5   8  19   4]
#  [  8  12   3   2   4 377  39]
#  [  4   0   1   0   5 110 117]]
# ========================================
#
# classifier: LGBMClassifier
# Accuracy score: 0.5933263816475496
# f1_score: 0.5933263816475496
# Precision :  0.5933263816475496
# Recall: 0.5933263816475496
# Confusion matrix:
#   [[ 74   2   0   1   3  28   9]
#  [  1  19   0   0   0  39   2]
#  [  5   0   1   0   0  10   3]
#  [  4   2   1   0   2  23   2]
#  [ 10   2   0   0   4  27   3]
#  [ 14   4   1   1   5 368  52]
#  [  3   2   0   0   3 126 103]]
# ========================================

# %% [markdown]
# Hyperparameter Tuning

# %%
param = {
        'penalty': ['l1'],
        'loss': ['hinge','squared_hinge'],
        'multi_class': ['ovr','crammer_singer'],
        'dual': [False],
        'intercept_scaling': [2,4,5],
        'C': [2]
        }

# %%
#train the model with given parameters using GridSearchCV
svc = LinearSVC()
GCV =  GridSearchCV(svc,param,cv = 3, verbose =2,n_jobs=-1)
GCV.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# GridSearchCV(cv=3, estimator=LinearSVC(), n_jobs=-1,
#              param_grid={'C': [2], 'dual': [False],
#                          'intercept_scaling': [2, 4, 5],
#                          'loss': ['hinge', 'squared_hinge'],
#                          'multi_class': ['ovr', 'crammer_singer'],
#                          'penalty': ['l1']},
#              verbose=2)

# %%
GCV.best_params_
# Out:
# {'C': 2,
#  'dual': False,
#  'intercept_scaling': 2,
#  'loss': 'squared_hinge',
#  'multi_class': 'ovr',
#  'penalty': 'l1'}

# %% [markdown]
# # Final model

# %%
model = LinearSVC(C=2,dual = False, loss='hinge',multi_class='crammer_singer', penalty ='l1',intercept_scaling=2)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

print("Jaccard score: {}".format(jaccard_score(y_test,y_pred,average='micro')))
print("Accuracy score: {}".format(accuracy_score(y_test,y_pred)))
print("f1_score: {}".format(f1_score(y_test,y_pred,average='micro')))
print("Precision : ", precision_score(y_test,y_pred,average='micro'))
print("Recall: {}".format(recall_score(y_test,y_pred,average='micro')))
#print("Hamming loss: ", hamming_loss(y_test,y_pred))
print("\nConfusion matrix: \n", confusion_matrix(y_test,y_pred))
# Out:
# Jaccard score: 0.4708588957055215
# Accuracy score: 0.6402502606882169
# f1_score: 0.6402502606882169
# Precision :  0.6402502606882169
# Recall: 0.6402502606882169
#
# Confusion matrix:
#  [[ 95   0   0   1   3  14   4]
#  [  1  27   0   0   3  26   4]
#  [  2   0   1   2   1  10   3]
#  [  3   1   0   2   6  20   2]
#  [  9   1   0   6   8  18   4]
#  [ 11  13   3   6   6 365  41]
#  [  5   0   1   1   5 109 116]]

# %%
model.predict(x_test)
# Out:
# array([0, 5, 6, 5, 0, 5, 5, 5, 6, 5, 5, 5, 5, 5, 6, 5, 2, 3, 5, 5, 5, 1,
#        5, 5, 1, 6, 0, 6, 5, 5, 6, 0, 5, 5, 5, 6, 6, 1, 5, 5, 5, 5, 5, 6,
#        5, 0, 6, 5, 0, 5, 0, 5, 5, 5, 5, 0, 5, 5, 4, 6, 5, 5, 6, 5, 5, 5,
#        6, 5, 5, 5, 5, 0, 5, 5, 5, 6, 0, 6, 5, 6, 6, 6, 6, 0, 5, 6, 5, 5,
#        0, 6, 5, 5, 0, 5, 5, 6, 0, 1, 5, 5, 5, 0, 6, 5, 5, 1, 5, 5, 0, 0,
#        6, 5, 5, 5, 6, 1, 5, 0, 6, 5, 5, 6, 5, 6, 6, 5, 5, 6, 0, 5, 6, 5,
#        5, 5, 5, 5, 2, 5, 5, 5, 0, 3, 4, 6, 1, 0, 5, 0, 5, 5, 0, 1, 5, 1,
#        0, 0, 0, 5, 2, 6, 0, 5, 5, 5, 5, 5, 0, 5, 5, 4, 5, 0, 1, 5, 5, 5,
#        5, 5, 5, 5, 5, 5, 1, 5, 5, 5, 5, 6, 6, 1, 1, 5, 4, 6, 0, 6, 5, 0,
#        6, 5, 5, 5, 5, 5, 4, 0, 5, 0, 6, 5, 5, 3, 0, 5, 0, 4, 5, 5, 1, 5,
#        5, 6, 5, 0, 5, 5, 6, 3, 6, 5, 5, 5, 5, 0, 5, 4, 5, 5, 5, 5, 0, 6,
#        4, 5, 5, 5, 1, 5, 5, 5, 0, 6, 5, 5, 4, 1, 5, 5, 0, 5, 5, 6, 5, 0,
#        5, 6, 0, 6, 6, 5, 5, 6, 5, 0, 6, 6, 5, 0, 6, 4, 6, 5, 5, 0, 5, 5,
#        5, 5, 5, 5, 3, 5, 3, 3, 5, 6, 6, 5, 5, 6, 5, 5, 5, 6, 6, 5, 3, 1,
#        5, 5, 5, 0, 0, 5, 5, 6, 5, 6, 5, 6, 0, 5, 5, 5, 5, 6, 5, 5, 5, 5,
#        5, 5, 5, 5, 5, 6, 5, 0, 5, 0, 5, 0, 5, 5, 6, 5, 5, 5, 5, 5, 4, 5,
#        0, 0, 4, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 0, 0, 5, 6, 4, 5, 5, 5,
#        5, 6, 6, 5, 5, 6, 1, 5, 6, 5, 0, 6, 5, 5, 1, 6, 5, 5, 0, 5, 1, 5,
#        6, 5, 5, 0, 5, 5, 5, 5, 5, 6, 5, 0, 5, 6, 5, 6, 5, 0, 5, 6, 1, 0,
#        5, 5, 5, 6, 5, 4, 3, 0, 5, 5, 5, 0, 5, 6, 5, 5, 5, 5, 5, 5, 0, 5,
#        6, 5, 5, 6, 5, 6, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 6, 6, 5, 6, 5, 0,
#        5, 5, 5, 5, 5, 6, 6, 0, 5, 6, 6, 6, 5, 5, 6, 6, 0, 4, 5, 5, 5, 5,
#        6, 5, 0, 5, 5, 5, 6, 5, 1, 6, 5, 5, 0, 5, 6, 5, 6, 5, 0, 6, 5, 5,
#        5, 5, 5, 5, 6, 5, 5, 3, 5, 4, 5, 1, 5, 6, 5, 6, 6, 5, 5, 5, 5, 6,
#        5, 5, 5, 6, 0, 5, 6, 5, 5, 2, 5, 5, 5, 6, 5, 0, 5, 5, 5, 5, 5, 5,
#        5, 0, 5, 5, 5, 0, 5, 6, 6, 5, 5, 1, 6, 5, 5, 5, 5, 5, 4, 5, 5, 5,
#        6, 5, 5, 5, 5, 5, 5, 1, 6, 5, 5, 5, 5, 5, 5, 6, 4, 0, 5, 4, 6, 5,
#        6, 0, 5, 5, 5, 6, 3, 1, 5, 0, 6, 0, 0, 5, 6, 1, 5, 5, 2, 5, 5, 1,
#        1, 5, 6, 5, 5, 4, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 5, 6, 1, 5,
#        1, 5, 5, 0, 5, 6, 0, 3, 6, 5, 5, 5, 5, 1, 5, 5, 5, 6, 5, 3, 5, 5,
#        5, 5, 5, 5, 5, 5, 5, 1, 5, 6, 5, 5, 5, 5, 5, 0, 4, 6, 5, 5, 5, 6,
#        6, 0, 5, 6, 1, 0, 5, 5, 5, 6, 5, 5, 6, 5, 5, 5, 5, 0, 5, 0, 5, 6,
#        5, 5, 5, 6, 5, 5, 6, 1, 5, 3, 5, 6, 3, 6, 5, 4, 6, 5, 5, 5, 6, 5,
#        5, 0, 0, 5, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 0, 5, 5, 6, 6, 5, 5, 5,
#        5, 5, 6, 5, 5, 6, 5, 5, 5, 6, 5, 5, 5, 6, 0, 4, 5, 0, 6, 5, 5, 1,
#        5, 0, 6, 5, 5, 5, 5, 0, 5, 5, 5, 5, 5, 0, 5, 5, 0, 5, 6, 6, 5, 5,
#        5, 5, 4, 0, 5, 5, 5, 6, 4, 5, 5, 5, 4, 5, 0, 6, 0, 5, 4, 1, 5, 5,
#        5, 5, 6, 5, 0, 6, 1, 0, 5, 6, 5, 6, 5, 6, 5, 5, 5, 5, 0, 5, 5, 5,
#        5, 5, 0, 6, 5, 5, 6, 6, 5, 1, 4, 5, 1, 5, 5, 5, 0, 5, 6, 4, 5, 5,
#        0, 4, 0, 5, 0, 5, 5, 6, 5, 5, 6, 0, 5, 1, 4, 5, 6, 6, 5, 5, 5, 5,
#        6, 0, 5, 5, 5, 0, 1, 5, 5, 5, 5, 5, 0, 5, 6, 5, 6, 5, 5, 5, 0, 5,
#        0, 6, 5, 5, 5, 0, 0, 5, 0, 0, 0, 5, 0, 6, 5, 5, 5, 0, 0, 5, 5, 5,
#        5, 5, 5, 4, 3, 0, 0, 0, 5, 5, 5, 5, 5, 3, 0, 5, 5, 6, 5, 3, 5, 5,
#        5, 5, 5, 5, 5, 6, 5, 0, 6, 5, 5, 5, 0])

# %% [markdown]
# # Prediction for test dataset using final model

# %%
#Lets load the test data set
test = pd.read_csv('test.csv')
test.head()
# Out:
#      ID                                              Title
# 0  3846                                   Spark Cheatsheet
# 1  3847             Review of Random forest code in Python
# 2  3848                  Chi-Sq Test for Numeric variables
# 3  3849  Prediction from loaded pickled file for single...
# 4  3850  Even after installing Anaconda on my PC, I am ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1649 entries, 0 to 1648
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      1649 non-null   int64
#  1   Title   1649 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 25.9+ KB

# %%
test.isna().sum()
# Out:
# ID       0
# Title    0
# dtype: int64

# %%
text_proc(test)

# %%
tfidf = TfidfVectorizer(analyzer='word',max_features = 2000)
x1 = tfidf.fit_transform(test.Title)

# %%
x1
# Out:
# <1649x2000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8125 stored elements in Compressed Sparse Row format>

# %%
x1.shape
# Out:
# (1649, 2000)

# %%
#lets predict the output
model.predict(x1)
# Out:
# array([5, 5, 6, ..., 5, 5, 5])

# %%
predictions = model.predict(x1)

# %%
pred=pd.DataFrame(predictions, columns = ['Target'])
pred
# Out:
#       Target
# 0          5
# 1          5
# 2          6
# 3          5
# 4          1
# ...      ...
# 1644       4
# 1645       6
# 1646       5
# 1647       5
# 1648       5
#
# [1649 rows x 1 columns]

# %%
x_test = pd.concat([test,pred], axis=1)
x_test
# Out:
#         ID                                              Title  Target
# 0     3846                                   spark cheatsheet       5
# 1     3847                   review random forest code python       5
# 2     3848                       chisq test numeric variables       6
# 3     3849  prediction load pickle file single instance input       5
# 4     3850  even instal anaconda pc unable access jupyter ...       1
# ...    ...                                                ...     ...
# 1644  5490       take variables train data randomforest model       4
# 1645  5491    ti ame series forecast reduce stationary series       6
# 1646  5492      data visualization text analysis twitter mine       5
# 1647  5493              cross validation strategy stack model       5
# 1648  5494        convert cross table straight table qlikview       5
#
# [1649 rows x 3 columns]

# %%
x_test.Target.value_counts()
# Out:
# 5    959
# 6    332
# 0    112
# 4     84
# 1     68
# 2     56
# 3     38
# Name: Target, dtype: int64

# %%
x_test.dtypes
# Out:
# ID         int64
# Title     object
# Target     int64
# dtype: object

# %%
x_test['Domain'] = x_test['Target'].replace({0: 'Career' ,
                                             1: 'Hackathons',
                                             2:'Misc',
                                             3: 'Other',
                                             4:'Resources',
                                             5: 'Techniques',
                                             6: 'Tools'})

# %%
x_test
# Out:
#         ID                                              Title  Target  \
# 0     3846                                   spark cheatsheet       5
# 1     3847                   review random forest code python       5
# 2     3848                       chisq test numeric variables       6
# 3     3849  prediction load pickle file single instance input       5
# 4     3850  even instal anaconda pc unable access jupyter ...       1
# ...    ...                                                ...     ...
# 1644  5490       take variables train data randomforest model       4
# 1645  5491    ti ame series forecast reduce stationary series       6
# 1646  5492      data visualization text analysis twitter mine       5
# 1647  5493              cross validation strategy stack model       5
# 1648  5494        convert cross table straight table qlikview       5
#
#           Domain
# 0     Techniques
# 1     Techniques
# 2          Tools
# 3     Techniques
# 4     Hackathons
# ...          ...
# 1644   Resources
# 1645       Tools
# 1646  Techniques
# 1647  Techniques
# 1648  Techniques
#
# [1649 rows x 4 columns]

# %%
 x_test.drop(columns = ['Title','Target'],inplace = True)

# %%
x_test
# Out:
#         ID      Domain
# 0     3846  Techniques
# 1     3847  Techniques
# 2     3848       Tools
# 3     3849  Techniques
# 4     3850  Hackathons
# ...    ...         ...
# 1644  5490   Resources
# 1645  5491       Tools
# 1646  5492  Techniques
# 1647  5493  Techniques
# 1648  5494  Techniques
#
# [1649 rows x 2 columns]

# %%
#saving the data into csv file
x_test.to_csv(r"solution_submission.csv")

# %%
x_test
# Out:
#         ID      Domain
# 0     3846  Techniques
# 1     3847  Techniques
# 2     3848       Tools
# 3     3849  Techniques
# 4     3850  Hackathons
# ...    ...         ...
# 1644  5490   Resources
# 1645  5491       Tools
# 1646  5492  Techniques
# 1647  5493  Techniques
# 1648  5494  Techniques
#
# [1649 rows x 2 columns]
